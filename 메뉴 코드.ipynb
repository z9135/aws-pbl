# %%
#식사 메뉴 골라주는 코드 골라준 메뉴는 언제 메뉴인지(아침, 점심, 저녁) 그날 년,월,일 db에 기록
import random
class Menu():
        
    def breakfast(self):
        
        a = random.randrange(1,8)
        if a==1 or a==5:
            print('한식')
            s = int(input('한식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.한식()
            else:
                print('맛있는 식사하세요!')
                
        elif a==2 or a==6:
            print('양식')
            s = int(input('양식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.양식()
            else:
                print('맛있는 식사하세요!') 
                
        elif a==3 or a==7:
            print('중식')
            s = int(input('중식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.중식()
            else:
                print('맛있는 식사하세요!')
                
        else :
            print('일식')
            s = int(input('일식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.일식()
            else:
                print('맛있는 식사하세요!')

    def lunch(self):
        
        a = random.randrange(1,8)
        if a==1 or a==5:
            print('한식')
            s = int(input('한식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.한식()
            else:
                print('맛있는 식사하세요!')
                
        elif a==2 or a==6:
            print('양식')
            s = int(input('양식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.양식()
            else:
                print('맛있는 식사하세요!') 
                
        elif a==3 or a==7:
            print('중식')
            s = int(input('중식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.중식()
            else:
                print('맛있는 식사하세요!')
                
        else :
            print('일식')
            s = int(input('일식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.일식()
            else:
                print('맛있는 식사하세요!')
                
    def dinner(self):
        
        a = random.randrange(1,8)
        if a==1 or a==5:
            print('한식')
            s = int(input('한식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.한식()
            else:
                print('맛있는 식사하세요!')
                
        elif a==2 or a==6:
            print('양식')
            s = int(input('양식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.양식()
            else:
                print('맛있는 식사하세요!') 
                
        elif a==3 or a==7:
            print('중식')
            s = int(input('중식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.중식()
            else:
                print('맛있는 식사하세요!')
                
        else :
            print('일식')
            s = int(input('일식에서 골라드릴 까요? \n1. 예\n2. 아니요\n'))
            if s == 1:
                b=Menu_l()
                b.일식()
            else:
                print('맛있는 식사하세요!')
            
class Menu_l():
    
    def 한식(slef):
        a = ['떡볶이','국밥','칼국수','비빔밥','불고기','백반','찌개','냉면','감자탕']
        b =random.randrange(0,8)
        print(a[b])
        
    def 양식(slef):
        a = ['스테이크','피자','토스트','샐러드','파스타','리조토','햄버거']
        b =random.randrange(0,6)
        print(a[b])
        
    def 중식(slef):
        a = ['짜장면','볶음밥','마라탕','훠궈','짬뽕','울면','꿔봐로우']
        b =random.randrange(0,6)
        print(a[b])
        
    def 일식(slef):
        a = ['라멘','초밥','덮밥','우동','돈까스']
        b =random.randrange(0,4)
        print(a[b])
            
def meal():
    while True:
        print('==========@^^@=========')
        a = int(input('아래의 번호를 선택해 주세요!\n1. 아침식사\n2. 점심식사\n3. 저녁식사\n4. 종료\n'))
        print('==========@^^@=========')
        if a==1:
            b=Menu()
            b.breakfast()
        elif a==2:
            b=Menu()
            b.lunch()
        elif a==3:
            b=Menu()
            b.dinner()
        elif a==4:
            break
        else:
            print('잘못 선택 하셨습니다.')
            
meal()
# Out:
# ==========@^^@=========
# 아래의 번호를 선택해 주세요!
# 1. 아침식사
# 2. 점심식사
# 3. 저녁식사
# 4. 종료
# 1
# ==========@^^@=========
# 양식
# 양식에서 골라드릴 까요?
# 1. 예
# 2. 아니요
# 2
# 맛있는 식사하세요!
# ==========@^^@=========
# 아래의 번호를 선택해 주세요!
# 1. 아침식사
# 2. 점심식사
# 3. 저녁식사
# 4. 종료
# 0
# ==========@^^@=========
# 잘못 선택 하셨습니다.
# ==========@^^@=========
# 아래의 번호를 선택해 주세요!
# 1. 아침식사
# 2. 점심식사
# 3. 저녁식사
# 4. 종료
# 4
# ==========@^^@=========
